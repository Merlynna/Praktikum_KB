# %% [markdown]
# ## Tampilkan File CSV

# %%
# Tampilkan File CSV secara full
import pandas as panda
df = panda.read_csv('Electric_Vehicle_Population_Data.csv')
df
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year
# 0       5YJ3E1EA0K   Thurston      Tumwater    WA      98512.0        2019  \
# 1       1N4BZ1DV4N     Island       Clinton    WA      98236.0        2022
# 2       5YJ3E1EA0L  Snohomish     Snohomish    WA      98290.0        2020
# 3       5YJ3E1EBXL       King       Seattle    WA      98134.0        2020
# 4       5YJSA1CP0D  Snohomish       Edmonds    WA      98020.0        2013
# ...            ...        ...           ...   ...          ...         ...
# 135033  5YJSA1E29L       King  Yarrow Point    WA      98004.0        2020
# 135034  5YJYGDEE7M       King        Burien    WA      98168.0        2021
# 135035  5YJSA1E51N     Pierce    Gig Harbor    WA      98335.0        2022
# 135036  KM8KMDAF3P      Grant       Ephrata    WA      98823.0        2023
# 135037  1FADP5CU4E     Kitsap  Port Orchard    WA      98366.0        2014
#
#            Make    Model                   Electric Vehicle Type
# ...

# %% [markdown]
# ## Tampilkan Data Teratas (Head) dan Terbawah (Tail)

# %%
# Data Teratas
df.head(10)
# Out:
#    VIN (1-10)     County        City State  Postal Code  Model Year    Make
# 0  5YJ3E1EA0K   Thurston    Tumwater    WA      98512.0        2019   TESLA  \
# 1  1N4BZ1DV4N     Island     Clinton    WA      98236.0        2022  NISSAN
# 2  5YJ3E1EA0L  Snohomish   Snohomish    WA      98290.0        2020   TESLA
# 3  5YJ3E1EBXL       King     Seattle    WA      98134.0        2020   TESLA
# 4  5YJSA1CP0D  Snohomish     Edmonds    WA      98020.0        2013   TESLA
# 5  WBY7Z8C5XJ     Chelan      Manson    WA      98831.0        2018     BMW
# 6  5YJ3E1EC1L  Snohomish  Marysville    WA      98271.0        2020   TESLA
# 7  WA1F2AFY7M  Snohomish     Edmonds    WA      98026.0        2021    AUDI
# 8  JTDKARFPXK   Thurston     Olympia    WA      98501.0        2019  TOYOTA
# 9  1N4AZ1CP2J   Thurston       Lacey    WA      98503.0        2018  NISSAN
#
#          Model                   Electric Vehicle Type
# 0      MODEL 3          Battery Electric Vehicle (BEV)  \
# ...

# %%
# Data Terbawah
df.tail(10)
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year
# 135028  7SAYGDEE6P       King      Bellevue    WA      98005.0        2023  \
# 135029  1G1RD6S56H      Clark     Vancouver    WA      98682.0        2017
# 135030  1C4JJXN68P       King        Seatac    WA      98148.0        2023
# 135031  7SAYGDEF4N       King    North Bend    WA      98045.0        2022
# 135032  5YJ3E1EC4L  Snohomish       Edmonds    WA      98020.0        2020
# 135033  5YJSA1E29L       King  Yarrow Point    WA      98004.0        2020
# 135034  5YJYGDEE7M       King        Burien    WA      98168.0        2021
# 135035  5YJSA1E51N     Pierce    Gig Harbor    WA      98335.0        2022
# 135036  KM8KMDAF3P      Grant       Ephrata    WA      98823.0        2023
# 135037  1FADP5CU4E     Kitsap  Port Orchard    WA      98366.0        2014
#
#              Make     Model                   Electric Vehicle Type
# 135028      TESLA   MODEL Y          Battery Electric Vehicle (BEV)  \
# ...

# %% [markdown]
# ## Tampilkan Mean

# %%
# Atribut Electric Range
df['Electric Range'].mean()
# Out:
# 74.59196368402733

# %%
# Atribut legislative District
df['Legislative District'].mean()
# Out:
# 29.504379258643468

# %% [markdown]
# ## Tampilkan Deskripsi

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP
# count  135030.000000  135038.000000   135037.000000  135037.000000  \
# mean    98171.001577    2019.662880       74.591964    1448.407325
# std      2450.367211       3.001676       98.744120    9683.658138
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98121.000000    2021.000000       21.000000       0.000000
# 75%     98370.000000    2022.000000      150.000000       0.000000
# max     99701.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         134726.000000    1.350380e+05       1.350300e+05
# mean              29.504379    2.063432e+08       5.297233e+10
# std               14.783780    8.582417e+07       1.635783e+09
# min                1.000000    4.385000e+03       1.081042e+09
# ...

# %% [markdown]
# ## Tampilkan Informasi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135038 entries, 0 to 135037
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         135038 non-null  object
#  1   County                                             135030 non-null  object
#  2   City                                               135030 non-null  object
#  3   State                                              135038 non-null  object
#  4   Postal Code                                        135030 non-null  float64
#  5   Model Year                                         135038 non-null  int64
#  6   Make                                               135038 non-null  object
#  7   Model                                              134789 non-null  object
# ...

# %% [markdown]
# ## Tampilkan Jumlah

# %%
df.isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 8
# City                                                   8
# State                                                  0
# Postal Code                                            8
# Model Year                                             0
# Make                                                   0
# Model                                                249
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         1
# Base MSRP                                              1
# Legislative District                                 312
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       8
# ...

# %% [markdown]
# ## Tampilkan Jumlah semua Nilai bernilai Objek menggunakan Loc

# %%
listData = "County", "City", "State", "Make", "Electric Vehicle Type", "Clean Alternative Fuel Vehicle (CAFV) Eligibility", "Electric Utility"
df.loc[0:135037, listData]
# Out:
#            County          City State     Make
# 0        Thurston      Tumwater    WA    TESLA  \
# 1          Island       Clinton    WA   NISSAN
# 2       Snohomish     Snohomish    WA    TESLA
# 3            King       Seattle    WA    TESLA
# 4       Snohomish       Edmonds    WA    TESLA
# ...           ...           ...   ...      ...
# 135033       King  Yarrow Point    WA    TESLA
# 135034       King        Burien    WA    TESLA
# 135035     Pierce    Gig Harbor    WA    TESLA
# 135036      Grant       Ephrata    WA  HYUNDAI
# 135037     Kitsap  Port Orchard    WA     FORD
#
#                          Electric Vehicle Type
# 0               Battery Electric Vehicle (BEV)  \
# 1               Battery Electric Vehicle (BEV)
# 2               Battery Electric Vehicle (BEV)
# 3               Battery Electric Vehicle (BEV)
# 4               Battery Electric Vehicle (BEV)
# ...                                        ...
# 135033          Battery Electric Vehicle (BEV)
# ...

# %% [markdown]
# ## Tampilkan Iloc

# %%
# Tampilkan Data Loncat 2 Atribut
df = panda.read_csv('Electric_Vehicle_Population_Data.csv')
df.iloc[:,::2]
# Out:
#         VIN (1-10)          City  Postal Code     Make
# 0       5YJ3E1EA0K      Tumwater      98512.0    TESLA  \
# 1       1N4BZ1DV4N       Clinton      98236.0   NISSAN
# 2       5YJ3E1EA0L     Snohomish      98290.0    TESLA
# 3       5YJ3E1EBXL       Seattle      98134.0    TESLA
# 4       5YJSA1CP0D       Edmonds      98020.0    TESLA
# ...            ...           ...          ...      ...
# 135033  5YJSA1E29L  Yarrow Point      98004.0    TESLA
# 135034  5YJYGDEE7M        Burien      98168.0    TESLA
# 135035  5YJSA1E51N    Gig Harbor      98335.0    TESLA
# 135036  KM8KMDAF3P       Ephrata      98823.0  HYUNDAI
# 135037  1FADP5CU4E  Port Orchard      98366.0     FORD
#
#                          Electric Vehicle Type  Electric Range
# 0               Battery Electric Vehicle (BEV)           220.0  \
# 1               Battery Electric Vehicle (BEV)             0.0
# 2               Battery Electric Vehicle (BEV)           266.0
# ...

# %%
# Tampilkan Data Loncat 3 Atribut
df = panda.read_csv('Electric_Vehicle_Population_Data.csv')
df.iloc[:,::3]
# Out:
#         VIN (1-10) State     Make
# 0       5YJ3E1EA0K    WA    TESLA  \
# 1       1N4BZ1DV4N    WA   NISSAN
# 2       5YJ3E1EA0L    WA    TESLA
# 3       5YJ3E1EBXL    WA    TESLA
# 4       5YJSA1CP0D    WA    TESLA
# ...            ...   ...      ...
# 135033  5YJSA1E29L    WA    TESLA
# 135034  5YJYGDEE7M    WA    TESLA
# 135035  5YJSA1E51N    WA    TESLA
# 135036  KM8KMDAF3P    WA  HYUNDAI
# 135037  1FADP5CU4E    WA     FORD
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility
# 0                 Clean Alternative Fuel Vehicle Eligible  \
# 1       Eligibility unknown as battery range has not b...
# 2                 Clean Alternative Fuel Vehicle Eligible
# 3                 Clean Alternative Fuel Vehicle Eligible
# 4                 Clean Alternative Fuel Vehicle Eligible
# ...                                                   ...
# 135033            Clean Alternative Fuel Vehicle Eligible
# 135034  Eligibility unknown as battery range has not b...
# ...

# %%
# Tampilkan Data Tiada Loncat
df = panda.read_csv('Electric_Vehicle_Population_Data.csv')
df.iloc[:,::]
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year
# 0       5YJ3E1EA0K   Thurston      Tumwater    WA      98512.0        2019  \
# 1       1N4BZ1DV4N     Island       Clinton    WA      98236.0        2022
# 2       5YJ3E1EA0L  Snohomish     Snohomish    WA      98290.0        2020
# 3       5YJ3E1EBXL       King       Seattle    WA      98134.0        2020
# 4       5YJSA1CP0D  Snohomish       Edmonds    WA      98020.0        2013
# ...            ...        ...           ...   ...          ...         ...
# 135033  5YJSA1E29L       King  Yarrow Point    WA      98004.0        2020
# 135034  5YJYGDEE7M       King        Burien    WA      98168.0        2021
# 135035  5YJSA1E51N     Pierce    Gig Harbor    WA      98335.0        2022
# 135036  KM8KMDAF3P      Grant       Ephrata    WA      98823.0        2023
# 135037  1FADP5CU4E     Kitsap  Port Orchard    WA      98366.0        2014
#
#            Make    Model                   Electric Vehicle Type
# ...

# %%
# Tampilkan Data Loncat 1 Atribut
df = panda.read_csv('Electric_Vehicle_Population_Data.csv')
df.iloc[:,::1]

# %% [markdown]
# ## Tampilkan Jumlah Baris dan Kolom

# %%
# Baris, Kolom
df.shape
# Out:
# (135038, 17)

# %% [markdown]
# ## Tampilkan Jumlah dari Kolom

# %%
# Jumlah Kota
df['County'].value_counts()
# Out:
# County
# King         70842
# Snohomish    15258
# Pierce       10410
# Clark         7997
# Thurston      4851
#              ...
# Platte           1
# St. Clair        1
# Oldham           1
# Larimer          1
# Nassau           1
# Name: count, Length: 169, dtype: int64

# %%
# Jumlah Pembuat
df['Make'].value_counts()
# Out:
# Make
# TESLA                   61808
# NISSAN                  13150
# CHEVROLET               11437
# FORD                     6897
# BMW                      5895
# KIA                      5491
# TOYOTA                   4883
# VOLKSWAGEN               3526
# VOLVO                    3221
# AUDI                     2727
# JEEP                     2615
# HYUNDAI                  2395
# CHRYSLER                 2237
# RIVIAN                   1806
# PORSCHE                   952
# FIAT                      807
# HONDA                     787
# MERCEDES-BENZ             777
# MITSUBISHI                748
# MINI                      742
# POLESTAR                  658
# SMART                     277
# SUBARU                    272
# JAGUAR                    222
# LINCOLN                   212
# LUCID                     141
# CADILLAC                  120
# LEXUS                      80
# GENESIS                    67
# LAND ROVER                 43
# FISKER                     15
# ...

# %%
# Jumlah Tipe
df['Electric Vehicle Type'].value_counts()
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            103882
# Plug-in Hybrid Electric Vehicle (PHEV)     31156
# Name: count, dtype: int64

# %%
# Jumlah Eligible
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Clean Alternative Fuel Vehicle Eligible                         61221
# Eligibility unknown as battery range has not been researched    56983
# Not eligible due to low battery range                           16834
# Name: count, dtype: int64

# %%
# Jumlah Utilitas
df['Electric Utility'].value_counts()
# Out:
# Electric Utility
# PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                                      49369
# PUGET SOUND ENERGY INC                                                             26606
# CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)                                       24867
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)                    7816
# BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY     6041
#                                                                                    ...
# CITY OF SEATTLE - (WA)                                                                 1
# BONNEVILLE POWER ADMINISTRATION||PENINSULA LIGHT COMPANY                               1
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF ASOTIN COUNTY                             1
# BONNEVILLE POWER ADMINISTRATION||NESPELEM VALLEY ELEC COOP, INC                        1
# ...

# %% [markdown]
# ## Tampilkan Jumlah dari kolom 4 hingga terakhir dan dari baris NIM (143) hingga terakhir

# %%
listData = "City", "State", "Postal Code", "Model Year", "Make", "Electric Vehicle Type", "Clean Alternative Fuel Vehicle (CAFV) Eligibility", "Electric Range", "Base MSRP", "Legislative District", "DOL Vehicle ID", "Vehicle Location", "Electric Utility", "2020 Census Tract"
df.loc[142:135037, listData]
# Out:
#                 City State  Postal Code  Model Year     Make
# 142          Clinton    WA      98236.0        2019   NISSAN  \
# 143          Olympia    WA      98513.0        2018    TESLA
# 144          Olympia    WA      98501.0        2017     FORD
# 145     Port Orchard    WA      98366.0        2019   TOYOTA
# 146          Pullman    WA      99163.0        2011   NISSAN
# ...              ...   ...          ...         ...      ...
# 135033  Yarrow Point    WA      98004.0        2020    TESLA
# 135034        Burien    WA      98168.0        2021    TESLA
# 135035    Gig Harbor    WA      98335.0        2022    TESLA
# 135036       Ephrata    WA      98823.0        2023  HYUNDAI
# 135037  Port Orchard    WA      98366.0        2014     FORD
#
#                          Electric Vehicle Type
# 142             Battery Electric Vehicle (BEV)  \
# 143             Battery Electric Vehicle (BEV)
# 144     Plug-in Hybrid Electric Vehicle (PHEV)
# ...
