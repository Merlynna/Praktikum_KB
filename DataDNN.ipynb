# %% [markdown]
# # Import Library

# %%
import tensorflow as tf
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### Link DataSet CSV : https://drive.google.com/file/d/1UvsonUWSBUJ5Rn4Ofb7VF_p8zOHgewwl/view?usp=drive_link

# %% [markdown]
# # Tampilkan Data CSV

# %%
# menggunakan Pandas
dataFrame = pd.read_csv("Electric_Vehicle_Population_Data.csv")
dataFrame
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year
# 0       5YJ3E1EA0K   Thurston      Tumwater    WA      98512.0        2019  \
# 1       1N4BZ1DV4N     Island       Clinton    WA      98236.0        2022
# 2       5YJ3E1EA0L  Snohomish     Snohomish    WA      98290.0        2020
# 3       5YJ3E1EBXL       King       Seattle    WA      98134.0        2020
# 4       5YJSA1CP0D  Snohomish       Edmonds    WA      98020.0        2013
# ...            ...        ...           ...   ...          ...         ...
# 135033  5YJSA1E29L       King  Yarrow Point    WA      98004.0        2020
# 135034  5YJYGDEE7M       King        Burien    WA      98168.0        2021
# 135035  5YJSA1E51N     Pierce    Gig Harbor    WA      98335.0        2022
# 135036  KM8KMDAF3P      Grant       Ephrata    WA      98823.0        2023
# 135037  1FADP5CU4E     Kitsap  Port Orchard    WA      98366.0        2014
#
#            Make    Model                   Electric Vehicle Type
# ...

# %% [markdown]
# # Lakukan Scaler

# %%
# Proses OrdinalEncoder
encoder = OrdinalEncoder()
dataFrame["Electric Vehicle Type"] = encoder.fit_transform(dataFrame[["Electric Vehicle Type"]])
dataFrame.head(10)
# Out:
#    VIN (1-10)     County        City State  Postal Code  Model Year    Make
# 0  5YJ3E1EA0K   Thurston    Tumwater    WA      98512.0        2019   TESLA  \
# 1  1N4BZ1DV4N     Island     Clinton    WA      98236.0        2022  NISSAN
# 2  5YJ3E1EA0L  Snohomish   Snohomish    WA      98290.0        2020   TESLA
# 3  5YJ3E1EBXL       King     Seattle    WA      98134.0        2020   TESLA
# 4  5YJSA1CP0D  Snohomish     Edmonds    WA      98020.0        2013   TESLA
# 5  WBY7Z8C5XJ     Chelan      Manson    WA      98831.0        2018     BMW
# 6  5YJ3E1EC1L  Snohomish  Marysville    WA      98271.0        2020   TESLA
# 7  WA1F2AFY7M  Snohomish     Edmonds    WA      98026.0        2021    AUDI
# 8  JTDKARFPXK   Thurston     Olympia    WA      98501.0        2019  TOYOTA
# 9  1N4AZ1CP2J   Thurston       Lacey    WA      98503.0        2018  NISSAN
#
#          Model  Electric Vehicle Type
# 0      MODEL 3                    0.0  \
# 1         LEAF                    0.0
# ...

# %%
dataFrame.dropna(inplace = True)
dataFrame.isna().any()
# Out:
# VIN (1-10)                                           False
# County                                               False
# City                                                 False
# State                                                False
# Postal Code                                          False
# Model Year                                           False
# Make                                                 False
# Model                                                False
# Electric Vehicle Type                                False
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    False
# Electric Range                                       False
# Base MSRP                                            False
# Legislative District                                 False
# DOL Vehicle ID                                       False
# Vehicle Location                                     False
# Electric Utility                                     False
# ...

# %%
# Menunjukkan bahwa data tidak ada yang bernilai null atau NaN
print("Jumlah record yang memiliki nilai null:")
print(dataFrame.isna().sum())
# Out:
# Jumlah record yang memiliki nilai null:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# ...

# %%
dataFrame.dropna(inplace = True)
dataFrame.isna().any()
# Out:
# VIN (1-10)                                           False
# County                                               False
# City                                                 False
# State                                                False
# Postal Code                                          False
# Model Year                                           False
# Make                                                 False
# Model                                                False
# Electric Vehicle Type                                False
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    False
# Electric Range                                       False
# Base MSRP                                            False
# Legislative District                                 False
# DOL Vehicle ID                                       False
# Vehicle Location                                     False
# Electric Utility                                     False
# ...

# %%
dataFrame.head(20)
# Out:
#     VIN (1-10)     County        City State  Postal Code  Model Year    Make
# 0   5YJ3E1EA0K   Thurston    Tumwater    WA      98512.0        2019   TESLA  \
# 1   1N4BZ1DV4N     Island     Clinton    WA      98236.0        2022  NISSAN
# 2   5YJ3E1EA0L  Snohomish   Snohomish    WA      98290.0        2020   TESLA
# 3   5YJ3E1EBXL       King     Seattle    WA      98134.0        2020   TESLA
# 4   5YJSA1CP0D  Snohomish     Edmonds    WA      98020.0        2013   TESLA
# 5   WBY7Z8C5XJ     Chelan      Manson    WA      98831.0        2018     BMW
# 6   5YJ3E1EC1L  Snohomish  Marysville    WA      98271.0        2020   TESLA
# 7   WA1F2AFY7M  Snohomish     Edmonds    WA      98026.0        2021    AUDI
# 8   JTDKARFPXK   Thurston     Olympia    WA      98501.0        2019  TOYOTA
# 9   1N4AZ1CP2J   Thurston       Lacey    WA      98503.0        2018  NISSAN
# 10  KNDCE3LG2K   Thurston     Olympia    WA      98501.0        2019     KIA
# ...

# %%
imputer = SimpleImputer(strategy='mean')
dataFrame["Electric Vehicle Type"] = imputer.fit_transform(dataFrame[["Electric Vehicle Type"]])

# %%
imputer
# Out:
# SimpleImputer()

# %%
dataFrame.head(5)
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year    Make
# 0  5YJ3E1EA0K   Thurston   Tumwater    WA      98512.0        2019   TESLA  \
# 1  1N4BZ1DV4N     Island    Clinton    WA      98236.0        2022  NISSAN
# 2  5YJ3E1EA0L  Snohomish  Snohomish    WA      98290.0        2020   TESLA
# 3  5YJ3E1EBXL       King    Seattle    WA      98134.0        2020   TESLA
# 4  5YJSA1CP0D  Snohomish    Edmonds    WA      98020.0        2013   TESLA
#
#      Model  Electric Vehicle Type
# 0  MODEL 3                    0.0  \
# 1     LEAF                    0.0
# 2  MODEL 3                    0.0
# 3  MODEL 3                    0.0
# 4  MODEL S                    0.0
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 0            Clean Alternative Fuel Vehicle Eligible           220.0  \
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           266.0
# ...

# %% [markdown]
# # Lakukan Split

# %%
# X = Feature
x = dataFrame['Legislative District']

# Y = Target
y = dataFrame['Electric Vehicle Type']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 45)

# Split Data Train = Train + Val

x_val = x_train.iloc[135038:]
y_val = y_train.iloc[135038:]

x_train = x_train.iloc[:135038]
y_train = y_train.iloc[:135038]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # X = Feature
# ----> 2 x = dataFrame['Legislative District']
#       4 # Y = Target
#       5 y = dataFrame['Electric Vehicle Type']
#
# NameError: name 'dataFrame' is not defined

# %% [markdown]
# # Membuat Arsitektur Deep Neural Network

# %%
modelData = Sequential([Dense(units = 5, activation = 'linear', input_shape = (None, 1))])

# %% [markdown]
# # Model Summary

# %%
modelData.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, None, 5)           10
#
# ...
# Total params: 10 (40.00 Byte)
# Trainable params: 10 (40.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %% [markdown]
# ### Model Compile

# %%
modelData.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# ### Model Fit

# %%
# modelData.fit(x = x_train, y = y_train, epochs = 50, validation_data = (x_val, y_val))
